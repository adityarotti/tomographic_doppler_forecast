# %%
import sys,os
sys.path.append(os.path.abspath('../'))
from modules import tomographic_doppler as tmd
# %pylab notebook
import collections
from modules import auto_doppler_cov as adc
from modules import cross_doppler_cov as cdc
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['beta']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
beta=1.23e-3
fct1=tmd.ska_spectroscopic_doppler_forecast(bnu=3.75)
fct1.init_camb(lmax=2048,limber_phi_lmin=300)
fct1.setup_obs_param(flux_cutoff=fct1.flux_cutoff_options[0],area_obs=30000.)
fct1.setup_window_functions(normalize=False,nzbin=1,z_olap=-0.01,taper_width=0.05)
fct1.return_spectra()

# fct2=tmd.ska_spectroscopic_doppler_forecast()
# fct2.init_camb(lmax=2048,limber_phi_lmin=300)
# fct2.setup_obs_param(flux_cutoff=fct2.flux_cutoff_options[0],area_obs=30000.)
# fct2.setup_window_functions(normalize=False,nzbin=2,z_olap=-0.01,taper_width=0.05)
# fct2.return_spectra()

# fct3=tmd.ska_spectroscopic_doppler_forecast()
# fct3.init_camb(lmax=2048,limber_phi_lmin=300)
# fct3.setup_obs_param(flux_cutoff=fct3.flux_cutoff_options[0],area_obs=30000.)
# fct3.setup_window_functions(normalize=False,nzbin=3,z_olap=-0.01,taper_width=0.05)
# fct3.return_spectra()

# fct4=tmd.ska_spectroscopic_doppler_forecast()
# fct4.init_camb(lmax=2048,limber_phi_lmin=300)
# fct4.setup_obs_param(flux_cutoff=fct4.flux_cutoff_options[0],area_obs=30000.)
# fct4.setup_window_functions(normalize=False,nzbin=4,z_olap=-0.01,taper_width=0.05)
# fct4.return_spectra()

# fct5=tmd.ska_spectroscopic_doppler_forecast()
# fct5.init_camb(lmax=2048,limber_phi_lmin=300)
# fct5.setup_obs_param(flux_cutoff=fct5.flux_cutoff_options[0],area_obs=30000.)
# fct5.setup_window_functions(normalize=False,nzbin=5,z_olap=-0.01,taper_width=0.05)
# fct5.return_spectra()

# fct8=tmd.ska_spectroscopic_doppler_forecast()
# fct8.init_camb(lmax=2048,limber_phi_lmin=300)
# fct8.setup_obs_param(flux_cutoff=fct8.flux_cutoff_options[0],area_obs=30000.)
# fct8.setup_window_functions(normalize=False,nzbin=8,z_olap=-0.01,taper_width=0.05)
# fct8.return_spectra()

# fct12=tmd.ska_spectroscopic_doppler_forecast()
# fct12.init_camb(lmax=2048,limber_phi_lmin=300)
# fct12.setup_obs_param(flux_cutoff=fct8.flux_cutoff_options[0],area_obs=30000.)
# fct12.setup_window_functions(normalize=False,nzbin=12,z_olap=-0.01,taper_width=0.05)
# fct12.return_spectra()

# %%
print np.array(fct1.nbar.values())/1e9
print np.array(fct2.nbar.values())/1e9
print np.array(fct12.nbar.values())/1e8
# Out:
# [ 4.2736914]
# [ 1.73542959  2.53826181]
# [ 1.3036557   2.06402167  2.7585718   3.33846369  3.78541996  4.09910498
#   4.28932636  4.37109709  4.36151479  4.27783079  4.13630752  3.95159968]

# %%
# fct=tmd.ska_spectroscopic_doppler_forecast()
# fct.init_camb(lmax=2048,limber_phi_lmin=300)
# fct.setup_window_functions(normalize=False,nzbin=3,z_olap=0.0,taper_width=0.05)

# fct1=tmd.ska_spectroscopic_doppler_forecast()
# fct1.init_camb(lmax=2048,limber_phi_lmin=300)
# fct1.setup_window_functions(normalize=False,nzbin=5,z_olap=0.0,taper_width=0.05)

# fct2=tmd.ska_spectroscopic_doppler_forecast()
# fct2.init_camb(lmax=2048,limber_phi_lmin=300)
# fct2.setup_window_functions(normalize=False,nzbin=20,z_olap=0.0,taper_width=0.05)
# fct.setup_radial_res()

# %%
figure()
for zp in fct5.z_centroid:
    plot(fct5.z,fct5.window[zp])
#     plot(fct.z,fct.tom_window[zp])

figure()
plot(fct5.z,fct5.total_window/fct5.gal_num_error_est)
plot(fct5.z,fct5.dndz)
plot(fct5.z_centroid,np.array(fct5.nbar.values()))
semilogy() 
# for zp in fct1.z_centroid:
#     plot(fct1.z,fct1.window[zp],"--")
# for zp in fct2.z_centroid:
#     plot(fct2.z,fct2.window[zp],"-.")
    
# figure()
# for zp in fct.z_centroid:
#     plot(fct.z,fct.dwindow[zp])
# for zp in fct1.z_centroid:
#     plot(fct1.z,fct1.dwindow[zp],"--")
# for zp in fct2.z_centroid:
#     plot(fct2.z,fct2.dwindow[zp],"-.")
    
# figure()
# plot(fct.z,fct.total_window)
# plot(fct.z,fct.dndz)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# []

# %%
# fct.return_spectra()
# fct1.return_spectra()
# fct2.return_spectra()

# figure()
# for key in fct.adr_d1d2.values():
#     plot(fct.ell,abs(fct.cls[key]),label=key)
# loglog()
# legend(loc=0)

# figure()
# for key in fct.adr_dg.values()[:5]:
#     plot(fct.ell,abs(fct.cls[key[0]]),label=key[0])
#     plot(fct.ell,abs(fct.cls[key[1]]),label=key[1])
# loglog()
# legend(loc=0)

figure()
for key in fct12.adr_auto.values()[:5]:
    plot(fct12.ell,abs(fct12.cls[key]),label=key)
    plot(fct12.ell,abs(fct12.nl[key]),label=key)
loglog()
legend(loc=0)

figure()
for key in fct8.adr_auto.values()[:5]:
    plot(fct8.ell,abs(fct8.cls[key]),label=key)
    plot(fct8.ell,abs(fct8.nl[key]),label=key)
loglog()
legend(loc=0)

figure()
for key in fct1.adr_auto.values()[:5]:
    plot(fct1.ell,abs(fct1.cls[key]),label=key)
    plot(fct1.ell,abs(fct1.nl[key]),label=key)
loglog()
legend(loc=0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fct1.calc_doppler_error()
fct2.calc_doppler_error()
fct3.calc_doppler_error()
fct4.calc_doppler_error()
fct5.calc_doppler_error()
fct8.calc_doppler_error()
fct12.calc_doppler_error()

# %%
figure()
plot(fct1.ell_max,fct1.err,"r-",label="1 bin")
# plot(fct1.ell_max,fct1.simple_err,"k--")
plot(fct2.ell_max,fct2.err,"g-",label="2 bin")
# plot(fct2.ell_max,fct2.simple_err,"g--")
plot(fct3.ell_max,fct3.err,"b-",label="3 bin")
# plot(fct3.ell_max,fct3.simple_err,"b--")
plot(fct4.ell_max,fct4.err,"y-",label="4 bin")
# plot(fct4.ell_max,fct4.simple_err,"y--")
plot(fct5.ell_max,fct5.err,"c-",label="5 bin")
# plot(fct5.ell_max,fct5.simple_err,"c--")
plot(fct8.ell_max,fct8.err,"m-",label="8 bin")
# plot(fct8.ell_max,fct8.simple_err,"m--")
plot(fct12.ell_max,fct12.err,"-",c="purple",label="12 bin")
# plot(fct12.ell_max,fct12.simple_err,"p--")
semilogy()
hlines(pi*(2.*beta/3.)**2.,0,max(fct1.ell_max),linestyle="dashed",label=r"Doppler signal")
semilogy() ; grid()
xlim(2,max(fct1.ell_max))
legend(loc=0)
xticks([256,512,768,1024,1280,1536,1792,2048],[256,512,768,1024,1280,1536,1792,2048])
xlabel("maximum multipole $\ell$")
ylabel(r"$\sigma_{N_1}$")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fct1.fsky
# Out:
# 0.7272205216643038

# %%
fct12.adr_d1d2
# Out:
# OrderedDict([(0, 'W1xW1'),
#              (1, 'W1xW3'),
#              (2, 'W1xW5'),
#              (3, 'W1xW7'),
#              (4, 'W1xW9'),
#              (5, 'W1xW11'),
#              (6, 'W1xW13'),
#              (7, 'W1xW15'),
#              (8, 'W1xW17'),
#              (9, 'W1xW19'),
#              (10, 'W1xW21'),
#              (11, 'W1xW23'),
#              (12, 'W3xW3'),
#              (13, 'W3xW5'),
#              (14, 'W3xW7'),
#              (15, 'W3xW9'),
#              (16, 'W3xW11'),
#              (17, 'W3xW13'),
#              (18, 'W3xW15'),
#              (19, 'W3xW17'),
#              (20, 'W3xW19'),
#              (21, 'W3xW21'),
#              (22, 'W3xW23'),
#              (23, 'W5xW5'),
#              (24, 'W5xW7'),
#              (25, 'W5xW9'),
#              (26, 'W5xW11'),
#              (27, 'W5xW13'),
#              (28, 'W5xW15'),
#              (29, 'W5xW17'),
#              (30, 'W5xW19'),
#              (31, 'W5xW21'),
# ...
